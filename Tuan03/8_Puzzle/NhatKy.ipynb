# %% [markdown]
# ## Bài 3: Giải bài toán 8-Puzzle bằng BFS
#
# - Mục tiêu: tìm chuỗi di chuyển ngắn nhất
# - Phương pháp: tìm kiếm theo chiều rộng

# %%
from B8_puzzleBFS import bfs

# %% [markdown]
# - BFS tối ưu nhưng tốn bộ nhớ
